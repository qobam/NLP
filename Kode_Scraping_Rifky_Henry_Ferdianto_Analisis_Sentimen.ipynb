# %% [markdown]
# <a href="https://colab.research.google.com/github/qobam/NLP/blob/main/Kode_Scraping_Rifky_Henry_Ferdianto_Analisis_Sentimen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import app, reviews_all, Sort
# Melakukan scraping ulasan dari aplikasi dengan package name "jp.konami.pesam"
scrapreview = reviews_all(
    "jp.konami.pesam",
    lang="id", # Mengatur bahasa ulasan ke Bahasa Indonesia
    country="id", # Mengatur negara ulasan ke Indonesia
    sort=Sort.MOST_RELEVANT, # Mengatur urutan ulasan berdasarkan yang paling relevant
    filter_score_with=None # Mengambil semua ulasan tanpa filter skor
)

# %%
import csv

# Menyimpan ulasan ke dalam file CSV
with open('ulasan_aplikasi_efootball.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom 'Review'
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
# Membuat DataFrame dari hasil scraping ulasan dan mengambil 20000 baris pertama
app_reviews_df = pd.DataFrame(scrapreview).head(20000)

# Menampilkan bentuk (jumlah baris dan kolom) dari DataFrame
app_reviews_df.shape

# Menampilkan lima baris pertama dari DataFrame
app_reviews_df.head()

# Menyimpan DataFrame ke dalam file CSV (opsional, bisa dihapus jika tidak perlu)
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  64ed3ad2-3c32-4730-920f-04aaf05e9360  Pengguna Google
# 1  d8e7da7c-0401-4647-b158-c3ad517d07c9  Pengguna Google
# 2  915b8a6e-c6ab-486c-b36d-ef60e91e14e0  Pengguna Google
# 3  486c39e6-4da8-48e7-a873-f4d928cc72ac  Pengguna Google
# 4  1bf71cbb-26ba-4232-a12e-e7cfd9bcd3ce  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  eFootball hadir dengan gameplay yang cukup mul...      4             49
# 1  overall oke, but ada beberapa yang disayangkan...      3            104
# 2  sumpah ya konami denger keluhan user ga sih? a...      2            307
# 3  buat konami please lah,jaringan di perbaiki la...      2            327
# 4  jujur, skrg ni game kurang banget gameplaynya ...      1           1099
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                9.5.0 2025-07-17 09:04:54         None      None      9.5.0
# 1                9.5.0 2025-07-11 14:26:44         None      None      9.5.0
# 2                9.5.0 2025-07-07 09:22:16         None      None      9.5.0
# 3                9.5.0 2025-07-03 13:37:33         None      None      9.5.0
# 4                9.5.0 2025-07-12 01:46:06         None      None      9.5.0

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df (tipe data, non-null count, dll.)
app_reviews_df.info()

# Menghitung jumlah nilai yang hilang (NaN) per kolom
print(app_reviews_df.isnull().sum())

# Menghitung jumlah baris yang terduplikasi dalam DataFrame
print(app_reviews_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22500 entries, 0 to 22499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              22500 non-null  object
#  1   userName              22500 non-null  object
#  2   userImage             22500 non-null  object
#  3   content               22500 non-null  object
#  4   score                 22500 non-null  int64
#  5   thumbsUpCount         22500 non-null  int64
#  6   reviewCreatedVersion  18804 non-null  object
#  7   at                    22500 non-null  datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            18804 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 1.9+ MB
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3696
# at                          0
# replyContent            22500
# repliedAt               22500
# appVersion               3696
# dtype: int64
# 3905
