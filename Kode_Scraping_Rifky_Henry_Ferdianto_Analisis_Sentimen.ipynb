# %% [markdown]
# <a href="https://colab.research.google.com/github/qobam/NLP/blob/main/Kode_Scraping_Rifky_Henry_Ferdianto_Analisis_Sentimen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
from google_play_scraper import app, reviews_all, Sort
# Melakukan scraping ulasan dari aplikasi dengan package name "jp.konami.pesam"
scrapreview = reviews_all(
    "com.worldance.drama",
    lang="id", # Mengatur bahasa ulasan ke Bahasa Indonesia
    country="id", # Mengatur negara ulasan ke Indonesia
    sort=Sort.MOST_RELEVANT, # Mengatur urutan ulasan berdasarkan yang paling relevant
    filter_score_with=None # Mengambil semua ulasan tanpa filter skor
)

# %%
import csv

# Menyimpan ulasan ke dalam file CSV
with open('ulasan_aplikasi_Melolo.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom 'Review'
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
# Menyimpan DataFrame ke dalam file CSV (opsional, bisa dihapus jika tidak perlu)
app_reviews_df.to_csv('ulasan_aplikasi_melolo.csv', index=False)

# %%
# Menampilkan lima baris pertama dari DataFrame
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  d8f6114b-8bbb-4eef-ab95-40fe32e08f53  Pengguna Google
# 1  2d14777d-f1c2-4b8a-9ee3-ed1223bba2ed  Pengguna Google
# 2  11175c41-add7-483d-a700-80f9e7e989c8  Pengguna Google
# 3  5087245f-196f-4d6d-bb94-3e14119bd312  Pengguna Google
# 4  2442d5d0-335e-4ad4-a0ee-7dc678a626d9  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  download cuma mau ngasih bintang satu, tolong ...      1            231
# 1  maaf kasik bintang 1 karena terkait masalah ja...      1             33
# 2  ga ada masalah apa apa sih,cuman ga suka aja s...      1              2
# 3  download aplikasi ini cuma mau ngasih bintang ...      1              1
# 4  awalnya bagus tapi lama2 kok gak bisa d putar ...      1              6
#
#   reviewCreatedVersion                  at  \
# 0                4.9.2 2025-07-17 08:04:17
# 1                4.9.2 2025-07-21 16:03:37
# 2                4.9.2 2025-07-22 12:01:48
# 3                4.9.2 2025-07-23 13:37:35
# 4                4.9.2 2025-07-22 10:31:58
#
#                                         replyContent           repliedAt  \
# 0  Mohon maaf atas ketidaknyamanan ini.Melolo ber... 2025-07-18 10:28:16
# 1  Mohon maaf atas ketidaknyamanan ini.Mohon teta... 2025-07-23 07:20:40
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0      4.9.2
# 1      4.9.2
# 2      4.9.2
# 3      4.9.2
# 4      4.9.2

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  d8f6114b-8bbb-4eef-ab95-40fe32e08f53  Pengguna Google
# 1  2d14777d-f1c2-4b8a-9ee3-ed1223bba2ed  Pengguna Google
# 2  11175c41-add7-483d-a700-80f9e7e989c8  Pengguna Google
# 3  5087245f-196f-4d6d-bb94-3e14119bd312  Pengguna Google
# 4  2442d5d0-335e-4ad4-a0ee-7dc678a626d9  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  download cuma mau ngasih bintang satu, tolong ...      1            231
# 1  maaf kasik bintang 1 karena terkait masalah ja...      1             33
# 2  ga ada masalah apa apa sih,cuman ga suka aja s...      1              2
# 3  download aplikasi ini cuma mau ngasih bintang ...      1              1
# 4  awalnya bagus tapi lama2 kok gak bisa d putar ...      1              6
#
#   reviewCreatedVersion                  at  \
# 0                4.9.2 2025-07-17 08:04:17
# 1                4.9.2 2025-07-21 16:03:37
# 2                4.9.2 2025-07-22 12:01:48
# 3                4.9.2 2025-07-23 13:37:35
# 4                4.9.2 2025-07-22 10:31:58
#
#                                         replyContent           repliedAt  \
# 0  Mohon maaf atas ketidaknyamanan ini.Melolo ber... 2025-07-18 10:28:16
# 1  Mohon maaf atas ketidaknyamanan ini.Mohon teta... 2025-07-23 07:20:40
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0      4.9.2
# 1      4.9.2
# 2      4.9.2
# 3      4.9.2
# 4      4.9.2

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df (tipe data, non-null count, dll.)
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52578 entries, 0 to 52577
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              52578 non-null  object
#  1   userName              52578 non-null  object
#  2   userImage             52578 non-null  object
#  3   content               52578 non-null  object
#  4   score                 52578 non-null  int64
#  5   thumbsUpCount         52578 non-null  int64
#  6   reviewCreatedVersion  47670 non-null  object
#  7   at                    52578 non-null  datetime64[ns]
#  8   replyContent          255 non-null    object
#  9   repliedAt             255 non-null    datetime64[ns]
#  10  appVersion            47670 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 4.4+ MB

# %%
# Menghitung jumlah nilai yang hilang (NaN) per kolom
print(app_reviews_df.isnull().sum())
# Out:
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     4908
# at                          0
# replyContent            52323
# repliedAt               52323
# appVersion               4908
# dtype: int64

# %%
# Menghitung jumlah baris yang terduplikasi dalam DataFrame
print(app_reviews_df.duplicated().sum())
# Out:
# 0
